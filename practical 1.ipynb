# %%
import platform 
#get os name 
os_name = platform.system()

#get os version 
os_version = platform.version()

# get system architecture 
architecture = platform.machine()

print("operation system name:",os_name)
print("operation system version:",os_version)
print("operation system architecture:",architecture)
# Out:
# operation system name: Windows
# operation system version: 10.0.26200
# operation system architecture: AMD64
